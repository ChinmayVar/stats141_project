# %% [markdown]
# ## 141 Project

# %%
import pandas as pd

df1 = pd.read_excel("MMCR Data Stats Class.xlsx", sheet_name="1999 to 2018")
df2 = pd.read_excel("MMCR Data Stats Class.xlsx", sheet_name="Primary OU")
df3 = pd.read_excel("MMCR Data Stats Class.xlsx", sheet_name="Primary excluding")
df4 = pd.read_excel("MMCR Data Stats Class.xlsx", sheet_name="Tarsus DBR")
df5 = pd.read_excel("MMCR Data Stats Class.xlsx", sheet_name="Control vs Tarsus")
df6 = pd.read_excel("MMCR Data Stats Class.xlsx", sheet_name="Tarsectomy")
df7 = pd.read_excel("MMCR Data Stats Class.xlsx", sheet_name="Same patient ")
# Out:
#      #        Patient_name  \
# 0  681       AGRAMA, FRANK
# 1  943       GAURI, INDIRA
# 2  679      ABISHOR, JANET
# 3  682  AKERS, MARI-ANNE S
# 4  396       Linda Russell
#
#   Original Dataset \nAll = 1999-2018\nRAG = 2013-2020\nDBR = 2021-2024  \
# 0                                          2013-2020
# 1                                          2021-2024
# 2                                          2013-2020
# 3                                          2013-2020
# 4                                          1999-2018
#
#   Home_address City State  Zip Phone          MRN                 Eye ID  ...  \
# 0          NaN  NaN   NaN  NaN   NaN  025-78-97 9        AGRAMA, FRANK_0  ...
# 1          NaN  NaN   NaN  NaN   NaN      1203647                    NaN  ...
# 2          NaN  NaN   NaN  NaN   NaN      5236956      ABISHOR, JANET_00  ...
# 3          NaN  NaN   NaN  NaN   NaN    030-28-18  AKERS, MARI-ANNE S_00  ...
# ...

# %% [markdown]
# df1, df2, df3 all have a # column and age that match up
